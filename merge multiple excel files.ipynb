# %%
import pandas as pd
import glob
#return all files in "sheets" folder using *
file_list= glob.glob(r"C:\Users\HP\Desktop\sheets/*")
file_list
# Out:
# ['C:\\Users\\HP\\Desktop\\sheets\\sheet1.xlsx',
#  'C:\\Users\\HP\\Desktop\\sheets\\sheet2.xlsx',
#  'C:\\Users\\HP\\Desktop\\sheets\\sheet3.xlsx']

# %%
#combine all files
files = []
for filename in file_list:
    df = pd.read_excel(filename)
    files.append(df)
frame = pd.concat(files, axis=0, ignore_index=True)

# %%
frame
# Out:
#                                  Region         Country      Item Type  \
# 0                    Sub-Saharan Africa         Burundi           Meat
# 1                                  Asia        Malaysia      Household
# 2     Central America and the Caribbean           Haiti     Vegetables
# 3                                Europe   Liechtenstein      Cosmetics
# 4                    Sub-Saharan Africa          Zambia         Cereal
# ...                                 ...             ...            ...
# 4995       Middle East and North Africa         Lebanon         Fruits
# 4996                             Europe  Czech Republic         Cereal
# 4997              Australia and Oceania         Vanuatu      Cosmetics
# 4998                             Europe      Luxembourg     Vegetables
# 4999                 Sub-Saharan Africa           Benin  Personal Care
#
#      Sales Channel Order Priority Order Date   Order ID  Ship Date  \
# ...

# %%
#save frame as an excel file

# %%
frame.to_excel(r"C:\Users\HP\Desktop\frame.xlsx",index =False)
